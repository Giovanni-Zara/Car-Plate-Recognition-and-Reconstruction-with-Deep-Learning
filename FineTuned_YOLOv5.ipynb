# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/ultralytics/yolov5 # Clone the repository
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17511, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 17511 (delta 5), reused 0 (delta 0), pack-reused 17493 (from 3)
# Receiving objects: 100% (17511/17511), 16.60 MiB | 29.82 MiB/s, done.
# Resolving deltas: 100% (11993/11993), done.

# %%
# !pip install -r /content/yolov5/requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 65.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 93.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 95.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 63.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !unzip -q "/content/drive/MyDrive/yolo_dataset.zip" -d "/content"

# %%
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"CUDA version: {torch.version.cuda}")
    print(f"Number of GPUs: {torch.cuda.device_count()}")
    for i in range(torch.cuda.device_count()):
        print(f"GPU {i}: {torch.cuda.get_device_name(i)}")
        print(f"  Memory: {torch.cuda.get_device_properties(i).total_memory / 1024**3:.1f} GB")
else:
    print("CUDA is not available. Make sure you have:")
    print("1. NVIDIA GPU with CUDA support")
    print("2. NVIDIA drivers installed")
    print("3. CUDA toolkit installed")
    print("4. PyTorch with CUDA support installed")
# Out:
# PyTorch version: 2.6.0+cu124
# CUDA available: True
# CUDA version: 12.4
# Number of GPUs: 1
# GPU 0: Tesla T4
#   Memory: 14.7 GB

# %%
# yolo finetuning

print("results saved: runs/train/")

# !python "/content/yolov5/train.py" \
    --img 640 \
    --batch 12 \
    --epochs 30 \
    --data "/content/licence_plate.yaml" \
    --weights yolov5s.pt \
    --project runs/train \
    --name YOLO_fine_tuned \
    --exist-ok \
    --device 0 \
    --save-period 5 \
    --patience 10
# Out:
# Output streaming troncato alle ultime 5000 righe.
#   with torch.cuda.amp.autocast(amp):
#       26/29       3.3G    0.01197    0.00269          0         26        640:  38% 263/687 [01:13<02:37,  2.70it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       26/29       3.3G    0.01197   0.002693          0         26        640:  38% 264/687 [01:13<02:21,  2.99it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       26/29       3.3G    0.01197   0.002696          0         22        640:  39% 265/687 [01:13<02:33,  2.75it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# ...

# %%
import shutil
import os

# Path to the best weights
best_weights_path = "/content/runs/train/YOLO_fine_tuned/weights/best.pt"

# Destination in Google Drive
drive_save_path = "/content/drive/MyDrive/yolo_models/best_yolo_finetuned.pt"

# Create destination folder if it doesn't exist
os.makedirs(os.path.dirname(drive_save_path), exist_ok=True)

# Copy the best.pt to your Drive
shutil.copy(best_weights_path, drive_save_path)

print(f"Model saved to: {drive_save_path}")
# Out:
# Model saved to: /content/drive/MyDrive/yolo_models/best_yolo_finetuned.pt

# %%
from google.colab import files

files.download(best_weights_path)

# %%
import shutil
import os
from google.colab import files

# Zip the directory
zip_path = "/content/runs_train.zip"
shutil.make_archive(zip_path.replace(".zip", ""), 'zip', "/content/runs/train")

# Download the zipped file
files.download(zip_path)
